# %%
import pickle

with open('/home/emerge/gpudrive/examples/eval/figures_data/test_scenario_ids.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# ['f021d1f198f7eeb2',
#  '3df7ab4e939ff08f',
#  '8a0bd53bbbc0d58b',
#  '1e6c4c92050bff70',
#  '2ecf5725e7f0f609',
#  '1ea69f2511d624f7',
#  '95f370d3a8dd6a5d',
#  '659dd1c77d2c824',
#  '121faa91f53a4e81',
#  '5f72be2f470af5f5',
#  'e7951bb8c4dabeb6',
#  'b4a3bfc8180e9077',
#  '50d24d5ac236c43f',
#  '538f370c50862a49',
#  '570607705da2f899',
#  'bab1e897d315abfd',
#  'ee648280ce58d30a',
#  '9629721da46ca2b3',
#  '8b122dede6040bc1',
#  '6602c5736c717846',
#  '29c1e8b32fe7dec0',
#  '5f8688b268a4b81',
#  '366a9c2a6c8bc2ec',
#  '5eee6b8c47b6e614',
#  '7d46f551e7915cb6',
#  '10ff9afe10c57497',
#  '39b5b72ca0adb881',
#  '9d86ecb4741fb80c',
#  '8b47fe6d35232c35',
#  '3b54a2fe03f86bd0',
#  'cf2775d0927dbb86',
#  '6b33472f668a7180',
#  '2392d88912cffcd0',
#  '569fd75c8d0423ad',
#  '7aaf47236067a589',
#  '5b93f49cb86a8bef',
#  'df982f01a51167bb',
#  'fa34376a3329799d',
#  'efd88141a693b25e',
#  '2004f3a0489fb1fd',
#  '22875ce43751868e',
#  'f03b71d48c867c87',
#  '1c686f411783465d',
# ...
