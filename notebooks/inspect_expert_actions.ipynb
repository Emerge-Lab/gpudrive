# %%
import torch
import matplotlib.pyplot as plt

# %%
inferred_expert_actions = torch.load('../notebooks/expert_actions.pt').detach().cpu().numpy()

# %%
inferred_expert_actions.shape
# Out:
# (6240, 3)

# %% [markdown]
# ### Index `2` seems to be the heading action

# %%
plt.plot(inferred_expert_actions[:, 2]);

# %% [markdown]
# ### Index `1` is acceleration (?)
# - Guessing its acceleration because there are more positive than negative values

# %%
plt.plot(inferred_expert_actions[:, 1]);

# %% [markdown]
# ### Index `0` is steering?

# %%
plt.plot(inferred_expert_actions[:, 0]);
